# %%
import pyfolio as pf
import pandas as pd

# %%
results = pd.read_pickle('perf.pickle')

# %%
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(results)

# %%
bench_rets = results['benchmark_period_return'] - results['benchmark_period_return'].shift(1)

# %%
bench_rets[0]=0

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import zipline
# %load_ext zipline

# %%
pf.create_full_tear_sheet(returns=returns, positions=positions, transactions=transactions,
                          live_start_date='2017-01-01', round_trips=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2016-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2021-09-30</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>11</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>55</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>18.013%</td>
#       <td>19.238%</td>
#       <td>19.025%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>17.549%</td>
#       <td>126.669%</td>
#       <td>166.447%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>17.179%</td>
#       <td>20.496%</td>
#       <td>19.955%</td>
#     </tr>
#     <tr>
# ...
